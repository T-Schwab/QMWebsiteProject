# %% [markdown]
# <a href="https://colab.research.google.com/github/T-Schwab/QMWebsiteProject/blob/main/DiD_RDD_Dams_South_Africa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install linearmodels
import pandas as pd
import seaborn as sns
import numpy as np
import plotly
import plotly.express as px
import warnings
from statsmodels.formula.api import ols
from statsmodels.iolib.summary2 import summary_col
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
sns.set(font_scale=1.5)
sns.set_style("white")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv("Subnational Unit-Data DiD South Africa.csv")

print(df.head())
# Out:
#   ISO3 National Unit        Name Admin Level          Metric  \
# 0  SWZ      Eswatini  Shiselweni      admin1  Incidence Rate
# 1  SWZ      Eswatini  Shiselweni      admin1  Incidence Rate
# 2  SWZ      Eswatini  Shiselweni      admin1  Incidence Rate
# 3  SWZ      Eswatini  Shiselweni      admin1  Incidence Rate
# 4  SWZ      Eswatini  Shiselweni      admin1  Incidence Rate
#
#                 Units  Year     Value
# 0  Cases per Thousand  2010  1.294336
# 1  Cases per Thousand  2011  1.018051
# 2  Cases per Thousand  2012  0.942140
# 3  Cases per Thousand  2013  1.996239
# 4  Cases per Thousand  2014  0.917405

# %% [markdown]
# MPUMALANGA (treatment group) AND HHOHHO (control group).

# %%
did=df[df['Name'].isin(['Mpumalanga', 'Hhohho'])] # subset the data to only include Mpumalanga and Hhohho

px.line(did, x='Year', y='Value', color='Name', title="Malaria Incidence Rates in Mpumalanga and Hhohho")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f5df8677-ff8c-413b-b63a-8d4faa07477c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5df8677-ff8c-413b-b63a-8d4faa07477c")) {                    Plotly.newPlot(                        "f5df8677-ff8c-413b-b63a-8d4faa07477c",                        [{"hovertemplate":"Name=Hhohho\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hhohho","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hhohho","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1.25636352518469,0.887154489190922,0.823594699836293,2.44154456524389,0.932059593128925,0.76430884459318,0.646068099836908,1.22566371359403,1.9430731364579,0.67241121835779,0.60909650272323,1.60834923955182,0.609993034220392],"yaxis":"y","type":"scatter"},{"hovertemplate":"Name=Mpumalanga\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mpumalanga","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mpumalanga","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1.50777620784873,2.15819165178805,1.73930043591715,3.33484445713586,3.33589759357757,1.32334954525354,1.65153475523011,8.01413331479511,3.54897716689834,2.12530274099862,2.40680244092047,1.7032777745579,1.24631258474482],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %%
did['post']=np.where(did['Year']>=2016,1,0) # create a variable that is 1 if the date is after the dam construction and 0 otherwise
did['treatment']=np.where(did['Name']=='Mpumalanga',1,0) # create a variable that is 1 if the state is Mpumalanga (i.e., the treatment group) and 0 for Hhohho (the control group)
did['post_treatment']=did['post']*did['treatment'] # create a variable that is 1 if the date is after dam construction and the state is Mpumalanga and 0 otherwise

# %%
did = did[(did['Year'] >= 2010) & (did['Year'] <= 2022)] # Filter the dataset to include years between 2010 and 2022
sns.lineplot(data=did, x='Year', y='Value', hue='Name')
plt.axvline(2016, color='black', linestyle='dashed', label='Mpumalanga Dam Construction')
plt.title('Malaria Incidence Rates in Mpumalanga and Hhohho')

plt.xlabel("Year")
plt.ylabel("Malaria Incidence Rate (Cases per Thousand)")

plt.legend()
plt.show()

# %%
did['category']=did['treatment'].astype(str)+did['post'].astype(str) # this variable is just for the plot below
sns.boxplot(x='category', y='Value', hue='treatment', data=did).set_xticklabels(["Pre x Treatment", "Pre x Control",'Post x Treatment','Post x Control'])
plt.xlabel('')
plt.title('Malaria Incidence Rates by Treatment and Post Treatment')
plt.show()

# %%
did_model = ols('Value ~  post + treatment + post_treatment', did).fit()
print(did_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.289
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     2.974
# Date:                Sat, 18 Jan 2025   Prob (F-statistic):             0.0538
# Time:                        15:40:56   Log-Likelihood:                -42.824
# No. Observations:                  26   AIC:                             93.65
# Df Residuals:                      22   BIC:                             98.68
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.1842      0.558      2.124      0.045       0.028       2.340
# post              -0.1392      0.760     -0.183      0.856      -1.715       1.437
# treatment          1.0491      0.788      1.330      0.197      -0.586       2.684
# post_treatment     0.8626      1.075      0.803      0.431      -1.366       3.091
# ==============================================================================
# Omnibus:                       32.753   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.892
# Skew:                           2.396   Prob(JB):                     3.68e-19
# Kurtosis:                      10.443   Cond. No.                         7.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
models=[] # create empty list to store the models
names=[] # create empty list to store the names of the models

for window in range(1,6): # loop through years from 2000 to 2020 in increments of 4
    did=df[(df['Year']>=(2016-window)) & (df['Year']<=(2016+window)) & df['Name'].isin(['Mpumalanga', 'Hhohho'])] # subset the data within the window of interest around 2014
    did['post']=np.where(did['Year']>=2016,1,0) # create a dummy variable indicating the period after the minimum wage increase
    did['treatment']=np.where(did['Name']=='Mpumalanga',1,0) # create a dummy variable for treatment
    did['post_treatment']=did['post']*did['treatment'] # create an interaction term between the post and treatment variables
    did_model = ols('Value ~ post + treatment + post_treatment', did).fit() # run the difference in difference model

    models.append(did_model) # append the model to the list of models
    names.append('± '+str(window)+' Year') # append the name of the model to the list of names

table=summary_col( # create a regression table
    models, # pass the models to the summary_col function
    stars=True, # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f', # set the decimal places to 3
    model_names=names, # set the names of the model
    info_dict = {"N":lambda x: "{0:d}".format(int(x.nobs))}) # add the number of observations to the table

print(table) # print the table
# Out:
# ===========================================================
#                ± 1 Year ± 2 Year ± 3 Year ± 4 Year ± 5 Year
# -----------------------------------------------------------
# Intercept      0.764    0.848    1.379    1.240    1.170*
#                (3.194)  (1.421)  (1.013)  (0.773)  (0.639)
# post           0.172    0.423    -0.258   -0.221   -0.052
#                (3.912)  (1.834)  (1.339)  (1.037)  (0.865)
# treatment      0.559    1.481    1.285    1.193    1.209
#                (4.518)  (2.009)  (1.432)  (1.093)  (0.904)
# post_treatment 3.338    1.652    1.428    1.337    0.916
#                (5.533)  (2.594)  (1.894)  (1.467)  (1.224)
# R-squared      0.493    0.460    0.368    0.371    0.330
# R-squared Adj. -0.267   0.191    0.179    0.236    0.218
# N              6        10       14       18       22
# ===========================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# KwaZulu-Natal (treatment group) and Shiselweni (control group).

# %%
did2=df[df['Name'].isin(['KwaZulu-Natal', 'Shiselweni'])] # subset the data to only include Mpumalanga and Hhohho

px.line(did2, x='Year', y='Value', color='Name', title="Malaria Incidence Rates in KwaZulu-Natal and Shiselweni") # plot the minimum wage over time
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7dda97f9-7195-4c24-92d2-b621a47a1f94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dda97f9-7195-4c24-92d2-b621a47a1f94")) {                    Plotly.newPlot(                        "7dda97f9-7195-4c24-92d2-b621a47a1f94",                        [{"hovertemplate":"Name=Shiselweni\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shiselweni","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Shiselweni","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1.29433580425011,1.01805129082925,0.942139814792903,1.99623903991386,0.917404906321949,0.786418858007056,0.63894264350971,1.08675825551782,1.47038544944085,0.52694126607964,0.481746851903634,1.06742416781219,0.435481263291369],"yaxis":"y","type":"scatter"},{"hovertemplate":"Name=KwaZulu-Natal\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KwaZulu-Natal","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"KwaZulu-Natal","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[0.571771086345848,0.796862512998792,0.613436785132769,1.10368401628979,1.11068461041182,0.401123718847175,0.464826933568325,2.21600999741715,0.937417864296484,0.558859676720752,0.528503185031025,0.344024170397055,0.229887298178426],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"co ...

# %%
did2['post']=np.where(did2['Year']>=2016,1,0) # create a variable that is 1 if the date is after the dam construction and 0 otherwise
did2['treatment']=np.where(did2['Name']=='KwaZulu-Natal',1,0) # create a variable that is 1 if the state is Mpumalanga (i.e., the treatment group) and 0 for Hhohho (the control group)
did2['post_treatment']=did2['post']*did2['treatment'] # create a variable that is 1 if the date is after dam construction and the state is Mpumalanga and 0 otherwise

# %%
did2 = did2[(did2['Year'] >= 2010) & (did2['Year'] <= 2022)] # Filter the dataset to include years between 2010 and 2022
sns.lineplot(data=did2, x='Year', y='Value', hue='Name')
plt.axvline(2016, color='black', linestyle='dashed', label='KwaZulu-Natal Dam Construction')
plt.title('Malaria Incidence Rates in KwaZulu-Natal and Shiselweni')
plt.xlabel("Year")
plt.ylabel("Malaria Incidence Rate (Cases per Thousand)")
plt.legend()
plt.show()

# %%
did2['category']=did2['treatment'].astype(str)+did2['post'].astype(str) # this variable is just for the plot below
sns.boxplot(x='category', y='Value', hue='treatment', data=did2).set_xticklabels(["Pre x Treatment", "Pre x Control",'Post x Treatment','Post x Control'])
plt.xlabel('')
plt.title('Malaria Incidence Rates by Treatment and Post Treatment')
plt.show()

# %%
did2_model = ols('Value ~  post + treatment + post_treatment', did2).fit()
print(did2_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.9720
# Date:                Sat, 18 Jan 2025   Prob (F-statistic):              0.424
# Time:                        15:40:57   Log-Likelihood:                -15.803
# No. Observations:                  26   AIC:                             39.61
# Df Residuals:                      22   BIC:                             44.64
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.1591      0.197      5.877      0.000       0.750       1.568
# post              -0.3437      0.269     -1.279      0.214      -0.901       0.214
# treatment         -0.3928      0.279     -1.409      0.173      -0.971       0.186
# post_treatment     0.3317      0.380      0.873      0.392      -0.457       1.120
# ==============================================================================
# Omnibus:                       16.072   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.056
# Skew:                           1.578   Prob(JB):                     0.000198
# Kurtosis:                       5.406   Cond. No.                         7.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
models=[] # create empty list to store the models
names=[] # create empty list to store the names of the models

for window in range(1,6): # loop through years from 2000 to 2020 in increments of 4
    did2=df[(df['Year']>=(2016-window)) & (df['Year']<=(2016+window)) & df['Name'].isin(['KwaZulu-Natal', 'Shiselweni'])] # subset the data within the window of interest around 2014
    did2['post']=np.where(did2['Year']>=2016,1,0) # create a dummy variable indicating the period after the minimum wage increase
    did2['treatment']=np.where(did2['Name']=='KwaZulu-Natal',1,0) # create a dummy variable for treatment
    did2['post_treatment']=did2['post']*did2['treatment'] # create an interaction term between the post and treatment variables
    did2_model = ols('Value ~ post + treatment + post_treatment', did2).fit() # run the difference in difference model

    models.append(did2_model) # append the model to the list of models
    names.append('± '+str(window)+' Year') # append the name of the model to the list of names

table=summary_col( # create a regression table
    models, # pass the models to the summary_col function
    stars=True, # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f', # set the decimal places to 3
    model_names=names, # set the names of the model
    info_dict = {"N":lambda x: "{0:d}".format(int(x.nobs))}) # add the number of observations to the table

print(table) # print the table
# Out:
# ===========================================================
#                ± 1 Year ± 2 Year ± 3 Year ± 4 Year ± 5 Year
# -----------------------------------------------------------
# Intercept      0.786    0.852*   1.233*** 1.161*** 1.132***
#                (0.904)  (0.433)  (0.353)  (0.275)  (0.226)
# post           0.076    0.213    -0.303   -0.320   -0.253
#                (1.107)  (0.559)  (0.467)  (0.368)  (0.305)
# treatment      -0.385   -0.096   -0.362   -0.353   -0.327
#                (1.278)  (0.612)  (0.499)  (0.388)  (0.319)
# post_treatment 0.863    0.237    0.475    0.453    0.290
#                (1.565)  (0.790)  (0.660)  (0.521)  (0.432)
# R-squared      0.283    0.119    0.060    0.069    0.068
# R-squared Adj. -0.791   -0.322   -0.223   -0.130   -0.087
# N              6        10       14       18       22
# ===========================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# REGRESSION DISCONTINUITY

# %% [markdown]
# #PART 1
# df["Year"] -= 2016
# #year dam was constructed
#
# #PART 2
# plt.figure(figsize=(8, 8))
# ax = plt.subplot(3,1,1)
# Mpumalanga_df = df[df['Name'] == 'Mpumalanga'] #change this to your second sub-national unit
# Mpumalanga_df.plot.scatter(x="Year", y="Value", ax=ax)
# plt.title("Incidence Before/After Dam Construction (Centered at 0)")
#
# #PART 3
# import statsmodels.formula.api as smf
#
# rdd_df = Mpumalanga_df.assign(threshold=(Mpumalanga_df["Year"] > 0).astype(int))
# model1 = smf.wls("Value ~ Year * threshold ", rdd_df).fit()
# print(model1.summary())
#
# #PART 4
# ate_pct = 100*((model1.params["threshold"] + model1.params["Intercept"])/model1.params["Intercept"] - 1)
# print("Dam construction increases the malaria incidence rate by {}%".format(np.round(ate_pct,2)))
#
# #PART 5
# ax = Mpumalanga_df.plot.scatter(x="Year", y="Value", color="C0")
# Mpumalanga_df.assign(predictions=model1.fittedvalues).plot(x="Year", y="predictions", ax=ax, color="C1")
# plt.title(f"Impact of Dams on Malaria Incidence: {np.round(ate_pct, 2)}% \n p={np.round(model1.pvalues['threshold'], 3)}, R2={np.round(model1.rsquared, 3)}")
# plt.show()

# %%
df["Year"] -= 2016
#year dam was constructed

# %%
plt.figure(figsize=(8, 8))
ax = plt.subplot(3, 1, 1)
KwaZuluNatal_df = df[df['Name'] == 'KwaZulu-Natal']
KwaZuluNatal_df.plot.scatter(x="Year", y="Value", ax=ax)
plt.title("Incidence Before/After Dam Construction (Centered at 0)")

ax = plt.subplot(3,1,2, sharex=ax)
Mpumalanga_df = df[df['Name'] == 'Mpumalanga']
Mpumalanga_df.plot.scatter(x="Year", y="Value", ax=ax)
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
import statsmodels.formula.api as smf

rdd_df = Mpumalanga_df.assign(threshold=(Mpumalanga_df["Year"] > 0).astype(int))
model1 = smf.wls("Value ~ Year * threshold ", rdd_df).fit()
print(model1.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.649
# Model:                            WLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     5.557
# Date:                Sat, 18 Jan 2025   Prob (F-statistic):             0.0195
# Time:                        15:40:57   Log-Likelihood:                -18.749
# No. Observations:                  13   AIC:                             45.50
# Df Residuals:                       9   BIC:                             47.76
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.1885      0.838      2.611      0.028       0.292       4.085
# Year               0.0128      0.232      0.055      0.957      -0.513       0.539
# threshold          4.8951      1.419      3.449      0.007       1.685       8.106
# Year:threshold    -1.1298      0.375     -3.014      0.015      -1.978      -0.282
# ==============================================================================
# Omnibus:                        0.556   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.757   Jarque-Bera (JB):                0.583
# Skew:                           0.366   Prob(JB):                        0.747
# Kurtosis:                       2.264   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ate_pct = 100*((model1.params["threshold"] + model1.params["Intercept"])/model1.params["Intercept"] - 1)

print("Dam construction increases the malaria incidence rate by {}%".format(np.round(ate_pct,2)))
# Out:
# Dam construction increases the malaria incidence rate by 223.67%

# %%
ax = Mpumalanga_df.plot.scatter(x="Year", y="Value", color="C0")
Mpumalanga_df.assign(predictions=model1.fittedvalues).plot(x="Year", y="predictions", ax=ax, color="C1")
plt.title(f"Impact of Dams on Malaria Incidence: {np.round(ate_pct, 2)}% \n p={np.round(model1.pvalues['threshold'], 3)}, R2={np.round(model1.rsquared, 3)}")

plt.xlabel("Year")
plt.ylabel("Malaria Incidence Rate (Cases per Thousand)")
plt.show()

# %%
#PART 1
df["Year"] -= 2016
#year dam was constructed

#PART 2
plt.figure(figsize=(8, 8))
ax = plt.subplot(3,1,1)
KwaZuluNatal_df = df[df['Name'] == 'KwaZulu-Natal'] #change this to your second sub-national unit
KwaZuluNatal_df.plot.scatter(x="Year", y="Value", ax=ax)
plt.title("Incidence Before/After Dam Construction (Centered at 0)")

#PART 3
import statsmodels.formula.api as smf

rdd_df2 = KwaZuluNatal_df.assign(threshold=(KwaZuluNatal_df["Year"] > 0).astype(int))
model2 = smf.wls("Value ~ Year * threshold ", rdd_df2).fit()
print(model2.summary())

#PART 4
ate_pct = 100*((model2.params["threshold"] + model2.params["Intercept"])/model2.params["Intercept"] - 1)
print("Dam construction increases the malaria incidence rate by {}%".format(np.round(ate_pct,2)))

#PART 5
ax = KwaZuluNatal_df.plot.scatter(x="Year", y="Value", color="C0")
KwaZuluNatal_df.assign(predictions=model2.fittedvalues).plot(x="Year", y="predictions", ax=ax, color="C1")
plt.title(f"Impact of Dam on Malaria Incidence: {np.round(ate_pct, 2)}% \n p={np.round(model2.pvalues['threshold'], 3)}, R2={np.round(model2.rsquared, 3)}")

plt.xlabel("Year")
plt.ylabel("Malaria Incidence Rate (Cases per Thousand)")

plt.show()
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.040
# Model:                            WLS   Adj. R-squared:                 -0.048
# Method:                 Least Squares   F-statistic:                    0.4551
# Date:                Sat, 18 Jan 2025   Prob (F-statistic):              0.514
# Time:                        15:40:58   Log-Likelihood:                -9.1011
# No. Observations:                  13   AIC:                             22.20
# Df Residuals:                      11   BIC:                             23.33
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        -52.6459     79.165     -0.665      0.520    -226.888     121.596
# Year              -0.0265      0.039     -0.675      0.514      -0.113       0.060
# threshold               0          0        nan        nan           0           0
# Year:threshold          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       19.839   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.665
# Skew:                           2.059   Prob(JB):                     0.000241
# Kurtosis:                       6.715   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Dam construction increases the malaria incidence rate by 0.0%
